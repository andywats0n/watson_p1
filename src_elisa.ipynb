# %%
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# target_city = input("Please input the city where you would like to move : ")
# radius=int(input("Please input the radius around the city : "))

target_city = 'atlanta'

params = {
    "address": target_city,
    "key": 'AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4 '
}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

# print(f" The Geocoordinates of {target_city} is")

# Run request
res = requests.get(base_url, params=params).json()
# res
# Out:
# {'results': [{'address_components': [{'long_name': 'Atlanta',
#      'short_name': 'Atlanta',
#      'types': ['locality', 'political']},
#     {'long_name': 'Fulton County',
#      'short_name': 'Fulton County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Georgia',
#      'short_name': 'GA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Atlanta, GA, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 33.8876179, 'lng': -84.289389},
#      'southwest': {'lat': 33.6478079, 'lng': -84.5518189}},
#     'location': {'lat': 33.7489954, 'lng': -84.3879824},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 33.8876179, 'lng': -84.289389},
#      'southwest': {'lat': 33.6478079, 'lng': -84.5518189}}},
#    'place_id': 'ChIJjQmTaV0E9YgRC2MLmS_e_mY',
# ...

# %%
target_coordinates = "33.8876179, -84.289389"
target_search="grocery_or_supermarket"
target_radius=8000
target_type= "grocery_or_supermarket"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CrQCJAEAAGjVfJzKzY3lJiXtmBkQET99Q1L1mNKXXfxT_7w4harKak_hco4iQGSz1n2XvBsO8ZPBR8NU2y2vvTH6UxKpH4Wi4abZiNkhNPlz44piUsXGPLgUlr9U4ZmfVO3v-BVaM-SwWOPYReLmPGtCzaiV8EHjkdqTp7WZUAHAvtDgRvSzpafqavMYa7Y5YJ86jKovzgVu6RBjXQxvPP00LudYlZbMaXFoWJag_3ce8WjWAYXT_ZVVYMJWZv6vBeWCWTwZYN24-NU1qGm6fPOILH5eIkdPGlliFHSY3PK9WzA-cO7q5nUQMoeUp-P5m7ytG-gJFSQCYEqdtj1mSlBWq5vEry1nCTcI4Vkb4VIxoMi5p1ogAU_JzgSkoqRCXwvE8V3WUCfpA62V2-sY4k27dbk9pzMSEK0l7rmW9bNIpjFV_LjtVi0aFNipHR143q3BsFeyJTiw2n7WvRqZ",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 33.9077452,
#                     "lng": -84.2881654
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.90929833029149,
#                         "lng": -84.2867063697085
#                     },
#                     "southwest": {
# ...

# %%
groceries_30341 = []
for item in places_data["results"]:
    groceries_30341.append(item["name"])
print(groceries_30341)
# Out:
# ['Hmart Doraville', 'Walmart Supercenter', 'ALDI', 'Walmart Supercenter', 'Publix Super Market at Oglethorpe Crossing', 'Publix Super Market at Perimeter', 'Publix Super Market at Shallowford Exchange', 'Atlanta Chinatown', 'Family Dollar', 'Publix Super Market at Lenox Marketplace', 'Publix Super Market at Town Brookhaven', 'The Fresh Market', 'Family Dollar', 'Publix Super Market at Briarcliff Village Shopping Center', 'Dinho Market of Atlanta', 'Manila Mart', 'Walmart Neighborhood Market', 'Walmart Neighborhood Market', 'Family Dollar', 'Supermercado Chicago']

# %%
n_groceries_30341=len(groceries_30341)
print(n_groceries_30341)
# Out:
# 20

# %%
target_coordinates = "33.8876179, -84.289389"
target_search="cafe"
target_radius=8000
target_type= "cafe"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

cafes_30341 = []
for item in places_data["results"]:
    cafes_30341.append(item["name"])
print(cafes_30341)

n_cafes_30341=len(cafes_30341)
print(n_cafes_30341)
# Out:
# ['HippoHopp Atlanta', "Auntie Anne's", 'Cafe Intermezzo', 'Einstein Bros. Bagels', 'Starbucks', "Alon's Bakery & Market", 'Sweet Hut Bakery Cafe', 'White Windmill Bakery and Cafe', 'la Madeleine French Bakery & Café Perimeter', 'Flying Biscuit Cafe - Brookhaven', 'Panera Bread', 'Cafe Bombay', 'Starbucks', 'Panera Bread', 'ChocoLate Coffee', 'ZenTea Tea House', 'Quickly Bubble Tea', 'The Coffee Bar', 'Waterview Cafe', 'Starbucks']
# 20

# %%
target_coordinates = "33.8876179, -84.289389"
target_search="clothing_store"
target_radius=8000
target_type= "clothing_store"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

clothingstores_30341 = []
for item in places_data["results"]:
    clothingstores_30341.append(item["name"])
print(clothingstores_30341)

n_clothingstores_30341=len(clothingstores_30341)
print(n_clothingstores_30341)
# Out:
# ['Gymboree', "Ticknors Men's Clothier", 'Nordstrom Perimeter Mall', 'Banana Republic', 'House of Hoops by Foot Locker', "Macy's", 'Marshalls', 'Liberator Flagship Store', 'JCPenney', 'REI', 'J.Crew', 'Target', 'Target', 'New York & Company', 'Gap', 'American Eagle Outfitters', 'Charlotte Russe', 'Target', 'Vans', 'Champs Sports']
# 20

# %%
target_coordinates = "33.8876179, -84.289389"
target_search="bus_station"
target_radius=8000
target_type= "bus_station"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

busstations_30341 = []
for item in places_data["results"]:
    busstations_30341.append(item["name"])
print(busstations_30341)

n_busstations_30341=len(busstations_30341)
print(n_busstations_30341)
# Out:
# ['Doraville Station', 'Buford Hwy @ Oakcliff Rd', 'Dunwoody Station', 'Buford Hwy & City Farmers Market', 'Chamblee Tucker Rd @ Carroll Cir', 'Buford Hwy NE @ 4995', 'Buford Hwy@Chamblee Tucker Rd', 'Chamblee Tucker Rd @ Cumberland Dr', 'Chamblee Tucker Rd @ Cumberland Dr', 'Chamblee Dunwoody Rd @ Buford Hwy NE', 'Chamblee Dunwoody Rd @ Clairview Dr', 'Buford & Chamblee Tucker', 'Chamblee Dunwoody Rd @ Buford Hwy NE', 'Buford Hwy NE @ Chamblee Dunwoody Rd', 'Chamblee Dunwoody Rd @ Clairview Dr', 'Buford Hwy NE @ Shallowford Rd', 'Shallowford Rd @ Buford Hwy', 'Shallowford Rd NE @ Chamblee Tucker Rd', 'Shallowford Rd NE @ Addison Dr', 'Shallowford Rd @ Buford Hwy']
# 20

# %%
target_coordinates = "33.8876179, -84.289389"
target_search="night_club"
target_radius=8000
target_type= "night_club"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

nightclubs_30341 = []
for item in places_data["results"]:
    nightclubs_30341.append(item["name"])
print(nightclubs_30341)

n_nightclubs_30341=len(nightclubs_30341)
print(n_nightclubs_30341)
# Out:
# ['The Mansion Elan', 'Oasis Goodtime Emporium', 'Sabor Discotheque', 'Life Dances On', 'El Noa Noa', 'Josephine', 'Karaoke Melody', 'The Coffee Bar', 'Therapy Lounge', 'Wooden Nickel', 'Atlanta Sound and Lighting', 'Karaoke Melody 2', 'Downwind Restaurant and Lounge', 'Happy Karaoke', 'Cephora Lounge', 'MTV Sports Bar & Lounge', 'Addis Lounge', 'Planet Hookah Cafe', 'Full room', 'Acapulcos']
# 20

# %%
target_coordinates = "33.8876179, -84.289389"
target_search="museum"
target_radius=8000
target_type= "museum"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

museums_30341 = []
for item in places_data["results"]:
    museums_30341.append(item["name"])
print(museums_30341)

n_museums_30341=len(museums_30341)
print(n_museums_30341)
# Out:
# ['Oglethorpe University Museum of Art', 'VSA Arts of Georgia, Inc.', 'Black History Store', 'Green Gap Technologies', 'Atlanta Art Conservation Center', 'Browning Courthouse', 'Studio DaVenzia', 'Palazzo DaVenzia', 'Bus Spot', 'Gipp Museums Inc', 'Wine Donation Center', 'sculpture Square Tower', 'Harbol Del Niño 21', 'Station lenox']
# 14

# %%
target_coordinates = "34.0296174, -84.2406057"
target_search="grocery_or_supermarket"
target_radius=8000
target_type= "grocery_or_supermarket"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

groceries_30022 = []
for item in places_data["results"]:
    groceries_30022.append(item["name"])
print(groceries_30022)

n_groceries_30022=len(groceries_30022)
print(n_groceries_30022)
# Out:
# ['Whole Foods Market', "Trader Joe's", 'Hmart Johns Creek', 'Walmart Supercenter', 'The Fresh Market', 'Publix Super Market at Alpharetta Commons', 'Publix Super Market at Alpharetta', 'Publix Super Market at The Village at Flynn Crossing', 'Ingles Market', 'Publix Super Market at Medlock Corners', 'IPANEMA BRAZILIAN BAKERY', 'Publix Aprons Cooking School at Alpharetta Commons', 'Publix Super Market at Haynes Bridge Village', 'Publix Super Market at Spalding Corners SC', 'Publix Super Market at Abbotts Village at Ocee', 'Whole Foods Market', "Publix Super Market at King's Market", 'ALDI', 'Publix Event Planning at Alpharetta Commons', 'Target Pharmacy']
# 20

# %%
target_coordinates = "34.0296174, -84.2406057"
target_search="cafe"
target_radius=8000
target_type= "cafe"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

cafes_30022 = []
for item in places_data["results"]:
    cafes_30022.append(item["name"])
print(cafes_30022)

n_cafes_30022=len(cafes_30022)
print(n_cafes_30022)
# Out:
# ['Starbucks', 'The Honey Baked Ham Company', 'Starbucks', 'Starbucks', "Papouli's Mediterranean Cafe & Market", 'Starbucks', 'Starbucks', "Dunkin' Donuts", 'Cloud 9 Hookah Lounge and Cafe', 'Udipi Cafe Eclectic Indian Vegetarian & Vegan, Swaminarayan, Jain Cuisine. OPEN On Labor Day!', 'Starbucks', 'Starbucks', 'Wild Wing Cafe', 'Panera Bread', "Auntie Anne's", 'Peachtree Growler Company', 'Roam Innovative Workplace: Alpharetta', 'Starbucks', 'Wildflour', "McDonald's"]
# 20

# %%
target_coordinates = "34.0296174, -84.2406057"
target_search="cloting_store"
target_radius=8000
target_type= "clothing_store"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

clothingstores_30022 = []
for item in places_data["results"]:
    clothingstores_30022.append(item["name"])
print(clothingstores_30022)

n_clothingstores_30022=len(clothingstores_30022)
print(n_clothingstores_30022)
# Out:
# ['Target', 'American Eagle Outfitters', 'Belk', 'Kid to Kid', 'Target', 'LOFT', 'LOFT', 'Party City', 'Forever 21', 'Walgreens', 'Marshalls', "DICK'S Sporting Goods", "Men's Wearhouse", 'Treasures Formals and Bridal', "Macy's", 'Old Navy', 'Lena Larose', 'buybuy BABY', 'Argan Salon & SPA', "francesca's"]
# 20

# %%
target_coordinates = "34.0296174, -84.2406057"
target_search="bus_station"
target_radius=8000
target_type= "bus_station"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

busstations_30022 = []
for item in places_data["results"]:
    busstations_30022.append(item["name"])
print(busstations_30022)

n_busstations_30022=len(busstations_30022)
print(n_busstations_30022)
# Out:
# ['Alexander Dr @ 4325', 'Brookside Pkwy @ Alexander Dr', 'Old Milton Pkwy @ Park Bridge Pkwy', 'Old Milton Pkwy @ Rockberry Ln', 'Brookside Pkwy @ 3775', 'Old Milton Pky @ Bridge Pointe Dr', 'Old Milton Pkwy @ Camden Way', 'Brookside Pkwy @ 3705', 'North Point Pky@Royal Blvd S', 'North Point Pkwy@Great Oaks Way', 'North Point Pkwy@ Royal Dr', 'North Point Pky@Royal Blvd S', 'North Point Pkwy @ Royal Dr', 'North Point Pkwy @ Great Oaks Way (S)', 'Old Milton Pkwy @ Brookside Pky', 'Old Milton Pkwy @ Cotton Creek Entry', 'North Point Pky @ 4501', 'North Point Pky@ Kimball Bridge Rd', 'North Point Pkwy @ Great Oaks Way', 'North Point Pkwy@ Great Oaks Way']
# 20

# %%
target_coordinates = "34.0296174, -84.2406057"
target_search="night_club"
target_radius=8000
target_type= "night_club"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

nightclubs_30022 = []
for item in places_data["results"]:
    nightclubs_30022.append(item["name"])
print(nightclubs_30022)

n_nightclubs_30022=len(nightclubs_30022)
print(n_nightclubs_30022)
# Out:
# ['Cloud 9 Hookah Lounge and Cafe', "Altobeli's Restaurant and Piano Bar'", 'Shlok Night Club', 'The Velvet Note', 'WaterCloud Vapor Company', 'Rising Cloud Vape', 'Bliss Bar and Lounge', 'EarthTran Global Limousine and Transportation Services', 'Wine Me Down', 'Pink Masquerade', 'ATLTonight LLC', 'Dr. Kiani, PhD', 'Sax']
# 13

# %%
target_coordinates = "34.0296174, -84.2406057"
target_search="museum"
target_radius=8000
target_type= "museum"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

museums_30022 = []
for item in places_data["results"]:
    museums_30022.append(item["name"])
print(museums_30022)

n_museums_30022=len(museums_30022)
print(n_museums_30022)
# Out:
# ['Autrey Mill Nature Preserve & Heritage Center', 'Carriage Lake']
# 2

# %%
target_coordinates = "33.9963225, -84.0083548"
target_search="grocery_or_supermarket"
target_radius=8000
target_type= "grocery_or_supermarket"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

groceries_30043 = []
for item in places_data["results"]:
    groceries_30043.append(item["name"])
print(groceries_30043)

n_groceries_30043=len(groceries_30043)
print(n_groceries_30043)
# Out:
# ['Hmart Suwanee', 'Walmart Supercenter', 'Walmart Supercenter', 'Walmart Supercenter', 'Publix Super Market at Old Peachtree', 'Family Dollar', 'Publix Super Market at Sugarloaf Crossing', 'Publix Super Market at The Shops at Huntcrest', 'Ingles Markets', 'Publix Facility Services', 'Honest Star Tropical Store', 'Publix Super Market at Merton Walk', 'Family Dollar', 'Super Mercado Jalisco', 'La Barata Foods ( Supermercado)', 'ALDI', 'La Victoria', 'Star Mart']
# 18

# %%
target_coordinates = "33.9963225, -84.0083548"
target_search="cafe"
target_radius=8000
target_type= "cafe"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

cafes_30043 = []
for item in places_data["results"]:
    cafes_30043.append(item["name"])
print(cafes_30043)

n_cafes_30043=len(cafes_30043)
print(n_cafes_30043)
# Out:
# ['Panera Bread', 'Cafe Aromas Bakery', 'Oyster Bay Seafood Cafe', 'Starbucks', 'Cupcake People', 'Panera Bread', 'The Peachtree Cafe', "Dunkin' Donuts", 'Boulder Creek Coffee', "Dunkin' Donuts", "McDonald's", "McDonald's", 'Einstein Bros. Bagels', 'Starbucks', "Dunkin' Donuts", 'The Honey Baked Ham Company', "McDonald's", 'Starbucks', 'Starbucks', "Mimi's Cafe"]
# 20

# %%
target_coordinates = "33.9963225, -84.0083548"
target_search="clothing_store"
target_radius=8000
target_type= "clothing_store"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

clothingstores_30043 = []
for item in places_data["results"]:
    clothingstores_30043.append(item["name"])
print(clothingstores_30043)

n_clothingstores_30043=len(clothingstores_30043)
print(n_clothingstores_30043)
# Out:
# ['Earthbound Trading Co.', "Levi's® Outlet Store at Sugarloaf Mills", 'Bass Pro Shops', 'Target', 'dressbarn', 'Wilsons Leather', 'FYE', 'Neiman Marcus Last Call', 'Foot Locker', 'Forever 21', 'Tommy Hilfiger Store', 'Journeys', 'Champs Sports', 'Gymboree Outlet', "The Children's Place Outlet", 'Old Navy', "Carter's", 'Crazy 8', 'Justice', 'GUESS Factory']
# 20

# %%
target_coordinates = "33.9963225, -84.0083548"
target_search="bus_station"
target_radius=8000
target_type= "bus_station"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

busstations_30043 = []
for item in places_data["results"]:
    busstations_30043.append(item["name"])
print(busstations_30043)

n_busstations_30043=len(busstations_30043)
print(n_busstations_30043)
# Out:
# ['Sugarloaf Mills Park & Ride', 'Lonnie Harvel Blvd & Student Center Entrance', 'Lonnie Harvel Blvd & Student Center Entrance OB', 'Lonnie Harvel Blvd & GGC Housing', 'Lonnie Harvel Blvd & GGC Housing OB', 'Lonnie Harvel Blvd & Sugar Oak Ln', 'Collins Hill Rd & Collins Industrial Way OB', 'Lonnie Harvel Blvd & Sugar Oak Ln OB', 'Walther Blvd & Parc 980 Apartments', 'Walther Blvd & Parc 980 Apartments OB', 'Walther Blvd & C3 Church', 'Walther Blvd & IHOP', 'Collins Hill Rd & Park Access Dr', 'Collins Hill Rd & Park Access Dr', 'Lawrenceville-Suwanee Rd & Lawrenceville Shopping Center', 'Lawrenceville Suwanee Rd & Verizon', 'Collins Hill Rd & Hurricane Shoals Rd IB', 'Phillip Blvd & Walther Blvd', 'Philip Blvd & Walther Rd', 'Lawrenceville Suwanee Rd & AMC']
# 20

# %%
target_coordinates = "33.9963225, -84.0083548"
target_search="night_club"
target_radius=8000
target_type= "night_club"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

nightclubs_30043 = []
for item in places_data["results"]:
    nightclubs_30043.append(item["name"])
print(nightclubs_30043)

n_nightclubs_30043=len(nightclubs_30043)
print(n_nightclubs_30043)
# Out:
# ['Inhale Smoke Shop & Lounge', 'Pk Tunn Lounge Bar and Grill', 'Vice Lounge', 'Rising Star Entertainment, Inc.', 'Echo Karaoke', 'Corix Utilities', 'coolray stadium', 'We Fix Everything', 'Hotbox Smoke Shop', 'Viral Vapes Suwanee', 'LIve Karaoke & Bar']
# 11

# %%
target_coordinates = "33.9963225, -84.0083548"
target_search="museum"
target_radius=8000
target_type= "museum"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

museums_30043 = []
for item in places_data["results"]:
    museums_30043.append(item["name"])
print(museums_30043)

n_museums_30043=len(museums_30043)
print(n_museums_30043)
# Out:
# ['Gwinnett Environmental and Heritage Center', 'Gwinnett Historic Courthouse', 'Discount Picture Framing', 'Hudgens Center For the Arts', 'Gwinnett History Museum', 'Greek Life Museum', 'Kids Fun Zone', 'Lawrenceville Female Seminary', 'Gwinnett Nashtitution Lake', 'JCH Centre for the Arts', 'Lawrenceville City Museum']
# 11

# %%
target_coordinates = "33.9253, -84.3857"
target_search="grocery_or_supermarket"
target_radius=8000
target_type= "grocery_or_supermarket"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

groceries_30328 = []
for item in places_data["results"]:
    groceries_30328.append(item["name"])
print(groceries_30328)

n_groceries_30328=len(groceries_30328)
print(n_groceries_30328)
# Out:
# ['Whole Foods Market', 'Walmart Supercenter', "Trader Joe's", 'The Fresh Market', 'Publix Super Market at Perimeter', 'Publix Super Market at Chastain Square', 'The Fresh Market', 'The Fresh Market', 'Publix Super Market at Dunwoody Hall Shopping Center', 'Whole Foods Market', 'Publix Super Market at Oglethorpe Crossing', "Trader Joe's", 'Walmart Supercenter', 'Publix Super Market at Sope Creek Crossing', 'Publix Super Market at Abernathy Square Shopping Center', 'Publix Super Market at Powers Ferry Village', 'ALDI', 'Publix Super Market at Trowbridge Crossing', 'Publix Super Market at The Prado', 'Shahrzad']
# 20

# %%
target_coordinates = "33.9253, -84.3857"
target_search="cafe"
target_radius=8000
target_type= "cafe"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

cafes_30328 = []
for item in places_data["results"]:
    cafes_30328.append(item["name"])
print(cafes_30328)

n_cafes_30328=len(cafes_30328)
print(n_cafes_30328)
# Out:
# ["Auntie Anne's", 'Flying Biscuit Cafe', 'Einstein Bros. Bagels', 'Cafe Intermezzo', 'la Madeleine French Bakery & Café Perimeter', 'Panera Bread', "Alon's Bakery & Market", 'Panera Bread', 'Starbucks', 'la Madeleine French Bakery & Café East Cobb', 'Waterview Cafe', 'Cafe 290', 'Muse for Life', 'Starbucks', 'The Market Plaza Shopping Center', "Sandy's Cafe", 'BP', 'The Honey Baked Ham Company', 'Starbucks', "McDonald's"]
# 20

# %%
target_coordinates = "33.9253, -84.3857"
target_search="clothing_store"
target_radius=8000
target_type= "clothing_store"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

clothingstores_30328 = []
for item in places_data["results"]:
    clothingstores_30328.append(item["name"])
print(clothingstores_30328)

n_clothingstores_30328=len(clothingstores_30328)
print(n_clothingstores_30328)
# Out:
# ['Gymboree', "Ticknors Men's Clothier", 'Nordstrom Perimeter Mall', 'Banana Republic', 'House of Hoops by Foot Locker', "Macy's", 'Marshalls', 'J.Crew', 'Target', 'New York & Company', 'Gap', 'American Eagle Outfitters', 'Charlotte Russe', 'Vans', 'Champs Sports', 'Body Central', 'REI', 'Bridals by Lori', "Dillard's", 'Know Style']
# 20

# %%
target_coordinates = "33.9253, -84.3857"
target_search="bus_station"
target_radius=8000
target_type= "bus_station"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

busstations_30328 = []
for item in places_data["results"]:
    busstations_30328.append(item["name"])
print(busstations_30328)

n_busstations_30328=len(busstations_30328)
print(n_busstations_30328)
# Out:
# ['Dunwoody Station', 'MT Vernon Hwy NE @ Sandy Springs Cir NE', 'MT Vernon Hwy NE @ Sandy Springs Cir NE', 'Roswell Rd @ Johnson Ferry Rd', 'Roswell Rd NE @ Sandy Springs Cir NE', 'Mt Vernon Hwy NE and Roswell Rd NE', 'Roswell Rd NE@Johnson Ferry Rd NE', 'Roswell Rd NE @ MT Vernon Hwy NE', 'Roswell Rd NE@MT Vernon Hwy NE', 'Roswell Rd NE@Sandy Springs Cir NE', 'Roswell Rd NE @ Hilderbrand Dr', 'Roswell Rd NE @ Hilderbrand Dr NE', 'Johnson Ferry Rd NE @ Roswell Rd', 'Roswell Rd NE @ Cromwell Rd NE', 'Roswell Rd NE@Vernon Woods Dr NE', 'MT Vernon Hwy@Boylston Dr', 'MT Vernon Hwy NW @ Hammond Dr NW', 'Roswell Rd NE @ Sandy Springs Pl', 'Roswell Rd NE @ Sandy Springs Pl NE', 'Johnson Ferry Rd@MT Vernon Hwy']
# 20

# %%
target_coordinates = "33.9253, -84.3857"
target_search="night_club"
target_radius=8000
target_type= "night_club"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

nightclubs_30328 = []
for item in places_data["results"]:
    nightclubs_30328.append(item["name"])
print(nightclubs_30328)

n_nightclubs_30328=len(nightclubs_30328)
print(n_nightclubs_30328)
# Out:
# ["Chef Rob's Caribbean Cafe & Upscale Lounge", 'Life Dances On', "Tony's Sports Bar & Grill", 'Doll House', 'Three Sheets', "johnny's hideaway", 'Cafe 290', "Bradley's Bar & Grill", 'Java Monkey Band', 'EarthTran Global Limousine and Transportation Services', 'ihookka Lounge & Cafe', 'Camps Kitchen and Bar', 'Cigar City Club', 'Chastain Park Amphatheater Loading Dock', 'Hampton Lake Pool', 'PM Pros Atlanta']
# 16

# %%
target_coordinates = "33.9253, -84.3857"
target_search="museum"
target_radius=8000
target_type= "museum"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

museums_30328 = []
for item in places_data["results"]:
    museums_30328.append(item["name"])
print(museums_30328)

n_museums_30328=len(museums_30328)
print(n_museums_30328)
# Out:
# ['Oglethorpe University Museum of Art', 'Williams Payne House', 'Kendall Art Advisory', 'Parque', 'Selma’s', 'Rock Cave', 'Harbol Del Niño 21', 'Gipp Museums Inc', 'Wine Donation Center']
# 9

# %%
target_coordinates = "33.9526002, -84.549934"
target_search="grocery_or_supermarket"
target_radius=8000
target_type= "grocery_or_supermarket"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

groceries_30062 = []
for item in places_data["results"]:
    groceries_30062.append(item["name"])
print(groceries_30062)

n_groceries_30062=len(groceries_30062)
print(n_groceries_30062)
# Out:
# ['Walmart Supercenter', 'Walmart Supercenter', 'Publix Super Market at Sandy Plains Exchange', 'Walmart Supercenter', 'ALDI', 'Publix Super Market at Barrett Parkway', 'Publix Super Market at Piedmont Commons Shopping Center', 'Publix Super Market at West Cobb Marketplace', 'BAG DEPOT', 'ALDI', 'Food Depot #25', 'Family Dollar', 'Family Dollar', 'Family Dollar', 'Publix Super Market at Towne Center Prado', 'Family Dollar', 'Publix Super Market at Macland Pointe Shopping Center', 'Family Dollar', 'Super mercado la Villa', 'Family Dollar']
# 20

# %%
target_coordinates = "33.9526002, -84.549934"
target_search="cafe"
target_radius=8000
target_type= "cafe"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

cafes_30062 = []
for item in places_data["results"]:
    cafes_30062.append(item["name"])
print(cafes_30062)

n_cafes_30062=len(cafes_30062)
print(n_cafes_30062)
# Out:
# ['Krispy Kreme Doughnuts', "Auntie Anne's", 'Starbucks', 'The Honey Baked Ham Company', 'Starbucks', 'The Vineyard Cafe and Dinner Theatre', 'Starbucks', 'Cool Beans Coffee Roasters', 'CANVAS café & bakery', 'Giga-Bites Cafe', "Dunkin' Donuts", "Carol's Cafe", "McDonald's", "McDonald's", "Dunkin' Donuts", "McDonald's", 'Sugar Cakes Patisserie & Bistro', 'Starbucks', 'Starbucks', 'Starbucks']
# 20

# %%
target_coordinates = "33.9526002, -84.549934"
target_search="clothing_store"
target_radius=8000
target_type= "clothing_store"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

clothingstores_30062 = []
for item in places_data["results"]:
    clothingstores_30062.append(item["name"])
print(clothingstores_30062)

n_clothingstores_30062=len(clothingstores_30062)
print(n_clothingstores_30062)
# Out:
# ['Target', "Plato's Closet", 'Abercrombie & Fitch', 'Adventure Outdoors', 'Marshalls', 'Target', "DICK'S Sporting Goods", 'Lane Bryant', 'Walgreens', 'Army-Navy Discount Center', 'Hodge Army & Navy Stores', 'Old Navy', 'Kudzu Tactical', 'TruPrep Emergency Preparedness', 'AEO & Aerie Store', "Lands' End", 'Natural Beauty Spa Boutique', 'Catherines', "David's Bridal", 'Justice']
# 20

# %%
target_coordinates = "33.9526002, -84.549934"
target_search="bus_station"
target_radius=8000
target_type= "bus_station"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

busstations_30062 = []
for item in places_data["results"]:
    busstations_30062.append(item["name"])
print(busstations_30062)

n_busstations_30062=len(busstations_30062)
print(n_busstations_30062)
# Out:
# ['bus stop (CCT)', 'Marietta Transfer Center', 'Anderson St + Atlanta St', 'S Marietta Pkwy + Roswell Street', 'N Marietta Pkwy + Whitlock Ave', 'Atlanta St + Waverly Way', 'Waverly Way + Atlanta St', 'Roswell St + Anderson St', 'Anderson St + Roswell St', 'S Marietta Pkwy + Crescent Cir', 'S Marietta Pkwy + Waverly Way', 'Cherokee St + Forest Ave', 'Roswell St + Alexander St', 'Church St + Kennesaw Ave', 'Atlanta St + Waterman St', 'Cherokee St + Blackwell St', 'S Marietta Pkwy + Atlanta St', 'Roswell St + Cole St', 'Atlanta St + S Marietta Pkwy', 'N Marietta Pkwy + Cherokee St']
# 20

# %%
target_coordinates = "33.9526002, -84.549934"
target_search="night_club"
target_radius=8000
target_type= "night_club"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

nightclubs_30062 = []
for item in places_data["results"]:
    nightclubs_30062.append(item["name"])
print(nightclubs_30062)

n_nightclubs_30062=len(nightclubs_30062)
print(n_nightclubs_30062)
# Out:
# ['The Place Bar · Grill · Nightclub', 'Highlands Grill Kennesaw', 'Electric Cowboy', 'Tofu Village Korean BBQ', 'Georgia Symphony Orchestra', 'Royal Cigar and Tobacco', 'La Pura Vida', 'El Camaleon', 'Blue Mist Cafe & Lounge', 'Rio Club & Lounge', "Jordan's Lounge", 'ihookka Lounge & Cafe', 'Mexico De Noche Night Club', 'uspo']
# 14

# %%
target_coordinates = "33.9526002, -84.549934"
target_search="museum"
target_radius=8000
target_type= "museum"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

museums_30062 = []
for item in places_data["results"]:
    museums_30062.append(item["name"])
print(museums_30062)

n_museums_30062=len(museums_30062)
print(n_museums_30062)
# Out:
# ['Gone With the Wind Museum', 'The Youth Museum', 'Marietta/Cobb Museum of Art', 'Marietta Museum of History', 'William Root House Museum and Garden', 'Marietta Fire Museum', 'Root House', 'Mayes Ward-Dobbins Funeral Home', 'Aviation Wing of Marietta', 'Delta Chi', 'Old Zion Heritage Museum', 'white water', 'CCC Campsite', 'Camp Brumby Cutoff', 'Pigeon Hill Ga', 'DOBBINS AIR FORCE BASE', 'Tooth of Ragnar', 'Exhibition hall']
# 18

# %%
target_coordinates = "33.75500, -84.39000"
target_search="grocery_or_supermarket"
target_radius=8000
target_type= "grocery_or_supermarket"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

groceries_30308 = []
for item in places_data["results"]:
    groceries_30308.append(item["name"])
print(groceries_30308)

n_groceries_30308=len(groceries_30308)
print(n_groceries_30308)
# Out:
# ['Whole Foods Market', "Trader Joe's", 'Walmart Supercenter', 'Publix Super Market at The Plaza Midtown', 'Walmart Supercenter', 'The Fresh Market', 'Publix Super Market at Piedmont', 'Publix Super Market at Ponce', 'Family Dollar', 'ALDI', 'Family Dollar', 'Publix Super Market In Atlantic Station', 'Publix Super Market at Ansley Mall', 'Publix Super Market at East Lake', 'Family Dollar', 'Family Dollar', 'Family Dollar', 'Family Dollar', 'Family Dollar', 'Publix Super Market at Howell Mill Village']
# 20

# %%
target_coordinates = "33.75500, -84.39000"
target_search="cafe"
target_radius=8000
target_type= "cafe"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

cafes_30308 = []
for item in places_data["results"]:
    cafes_30308.append(item["name"])
print(cafes_30308)

n_cafes_30308=len(cafes_30308)
print(n_cafes_30308)
# Out:
# ['The Flying Biscuit Cafe', "Mary Mac's Tea Room", 'The Flying Biscuit Cafe', 'Cafe Intermezzo', 'The Defoor Centre', "Dunkin'", 'West Egg Cafe', 'Barnes & Noble', 'Empire State South', 'Condesa Coffee', 'Revelator Coffee Grant Park', 'Panera Bread', 'No Mas! Cantina', 'Home grown GA Restaurant', 'Krispy Kreme', 'Flying Biscuit Café', 'Organogold Coffee', 'Starbucks', 'Octane', "Alon's Bakery & Market"]
# 20

# %%
target_coordinates = "33.75500, -84.39000"
target_search="clothing_store"
target_radius=8000
target_type= "clothing_store"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

clothingstores_30308 = []
for item in places_data["results"]:
    clothingstores_30308.append(item["name"])
print(clothingstores_30308)

n_clothingstores_30308=len(clothingstores_30308)
print(n_clothingstores_30308)
# Out:
# ['Target', 'H&M', 'Target', 'Walgreens', 'Kids Foot Locker', 'Jos. A. Bank', 'Norcostco Atlanta Costume', 'Tokyo Valentino', "Dillard's", 'lululemon', 'Pink Heart Inc', "Walter's Clothing", 'T.J. Maxx', 'Gombeyza', 'Wish', 'Old Navy', 'Lane Bryant', 'Urban Outfitters', 'Gap', 'Costumes, etc...']
# 20

# %%
target_coordinates = "33.75500, -84.39000"
target_search="bus_station"
target_radius=8000
target_type= "bus_station"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

busstations_30308 = []
for item in places_data["results"]:
    busstations_30308.append(item["name"])
print(busstations_30308)

n_busstations_30308=len(busstations_30308)
print(n_busstations_30308)
# Out:
# ['Atlanta Braves Shuttle Drop-off', 'MARTA', 'Atlanta Bus Station', 'Civic Center Marta Station (Northbound)', 'Civic Center MARTA Station', 'Arts Center Transit Station', 'Ajax Bus Services', 'bus stop', 'Peachtree St NE @ Edgewood Ave SE', 'Marietta St NW @ Broad St (Five Points Station)', 'Marietta St NW @ Peachtree St', 'Edgewood Ave @ Peachtree St', 'Peachtree St @ Decatur St', 'Forsyth St + Marietta St', 'Peachtree St @ Auburn Ave NE', 'Peachtree St NW @ Poplar St', 'Marietta St NW @ Fairlie St NW', 'Peachtree St @ Wall St (Five Points Station)', 'Peachtree St. at Five Points Marta Station', 'Pryor St SE @ Wall St SE']
# 20

# %%
target_coordinates = "33.75500, -84.39000"
target_search="night_club"
target_radius=8000
target_type= "night_club"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

nightclubs_30308 = []
for item in places_data["results"]:
    nightclubs_30308.append(item["name"])
print(nightclubs_30308)

n_nightclubs_30308=len(nightclubs_30308)
print(n_nightclubs_30308)
# Out:
# ['The Cheetah', "Kat's Cafe", 'Loca Luna', 'The EARL', 'Magic City', 'Compound', 'Clermont Lounge', 'Thrive', 'Lava Lounge', 'the Sound Table', 'Swinging Richards', 'The Drunken Unicorn', 'Halo Lounge', 'Lumen - Lobby Bar', 'DrinkShop', 'Cafe Circa', 'Apres Diem', 'Rain NightClub & Lounge', 'Sutra Lounge', '529 Bar']
# 20

# %%
target_coordinates = "33.75500, -84.39000"
target_search="museum"
target_radius=8000
target_type= "museum"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

museums_30308 = []
for item in places_data["results"]:
    museums_30308.append(item["name"])
print(museums_30308)

n_museums_30308=len(museums_30308)
print(n_museums_30308)
# Out:
# ['High Museum of Art', 'Martin Luther King, Jr. National Historical Park', 'Fernbank Museum of Natural History', 'Bodies The Exhibition', 'Margaret Mitchell House', 'Center For Puppetry Arts', 'Rhodes Hall', 'Jimmy Carter Presidential Library and Museum', "Children's Museum of Atlanta", 'Georgia State Capitol', 'Fernbank Science Center', 'Michael C. Carlos Museum', 'Museum of Design Atlanta (MODA)', 'William Breman Jewish Heritage Museum', 'Museum of Contemporary Art of Georgia', "The Wren's Nest", 'Hammond House Museum', 'Apex Museum', 'Renewable Bioproducts Institute (Georgia Tech)', 'Mandarin Antiques']
# 20

# %%
target_coordinates = "33.94278, -84.31778"
target_search="grocery_or_supermarket"
target_radius=8000
target_type= "grocery_or_supermarket"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

groceries_30338 = []
for item in places_data["results"]:
    groceries_30338.append(item["name"])
print(groceries_30338)

n_groceries_30338=len(groceries_30338)
print(n_groceries_30338)
# Out:
# ['Hmart Doraville', 'Walmart Supercenter', 'Whole Foods Market', 'Walmart Supercenter', "Trader Joe's", 'Publix Super Market at Perimeter', 'The Fresh Market', 'Publix Super Market at Oglethorpe Crossing', 'Publix Super Market at Dunwoody Hall Shopping Center', 'Family Dollar', 'Publix Super Market at Dunwoody Place Shopping Center', 'Publix Super Market at Abernathy Square Shopping Center', 'Atlanta Chinatown', 'Walmart Neighborhood Market', 'ALDI', 'Publix Super Market at Trowbridge Crossing', 'Dinho Market of Atlanta', 'Manila Mart', 'Publix Super Market at Peachtree Square Shopping Center', 'Publix Super Market at Spalding Corners SC']
# 20

# %%
target_coordinates = "33.94278, -84.31778"
target_search="cafe"
target_radius=8000
target_type= "cafe"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

cafes_30338 = []
for item in places_data["results"]:
    cafes_30338.append(item["name"])
print(cafes_30338)

n_cafes_30338=len(cafes_30338)
print(n_cafes_30338)
# Out:
# ["Auntie Anne's", 'Einstein Bros. Bagels', 'Cafe Intermezzo', 'Flying Biscuit Cafe', 'Panera Bread', 'la Madeleine French Bakery & Café Perimeter', "Alon's Bakery & Market", 'Panera Bread', 'Sweet Hut Bakery Cafe', 'Starbucks', 'White Windmill Bakery and Cafe', 'Panera Bread', 'Cloud 9 Hookah Lounge and Cafe', 'Waterview Cafe', 'Cafe 290', 'Starbucks', 'Muse for Life', "Sandy's Cafe", 'ZenTea Tea House', 'Starbucks']
# 20

# %%
target_coordinates = "33.94278, -84.31778"
target_search="clothing_store"
target_radius=8000
target_type= "clothing_store"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

clothingstores_30338 = []
for item in places_data["results"]:
    clothingstores_30338.append(item["name"])
print(clothingstores_30338)

n_clothingstores_30338=len(clothingstores_30338)
print(n_clothingstores_30338)
# Out:
# ['Gymboree', "Ticknors Men's Clothier", 'Nordstrom Perimeter Mall', 'Banana Republic', 'House of Hoops by Foot Locker', "Macy's", 'Marshalls', 'J.Crew', 'Liberator Flagship Store', 'Target', 'New York & Company', 'Gap', 'American Eagle Outfitters', 'Charlotte Russe', 'Vans', 'Champs Sports', 'Body Central', 'REI', "Dillard's", 'Know Style']
# 20

# %%
target_coordinates = "33.94278, -84.31778"
target_search="bus_station"
target_radius=8000
target_type= "bus_station"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

busstations_30338 = []
for item in places_data["results"]:
    busstations_30338.append(item["name"])
print(busstations_30338)

n_busstations_30338=len(busstations_30338)
print(n_busstations_30338)
# Out:
# ['Dunwoody Station', 'Doraville Station', 'Buford Hwy @ Oakcliff Rd', 'Publix', 'MT Vernon Rd@Vermack Rd', 'MT Vernon Rd@Manhasset Dr', 'MT Vernon Rd@Vernon Ridge Dr', 'MT Vernon Rd@Vernon Ridge Dr', 'MT Vernon Rd@Stratham Dr', 'MT Vernon Rd@Stratham Dr', 'MT Vernon Rd@Meadow Lake Dr', 'MT Vernon Rd@Meadow Lake Dr', 'Peeler Rd@Olde Village Ln', 'Peeler Rd@Olde Village Ln', 'MT Vernon Rd@Dunwoody Village Pkwy', 'Peeler Rd@Equestrian Way', 'Tilly Mill Rd@Lakesprings Way', 'Peeler Rd @ Adams Rd', 'Tilly Mill Rd@Holland CT', 'Dunwoody Village Pky @ MT Vernon Rd']
# 20

# %%
target_coordinates = "33.94278, -84.31778"
target_search="night_club"
target_radius=8000
target_type= "night_club"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

nightclubs_30338 = []
for item in places_data["results"]:
    nightclubs_30338.append(item["name"])
print(nightclubs_30338)

n_nightclubs_30338=len(nightclubs_30338)
print(n_nightclubs_30338)
# Out:
# ["Chef Rob's Caribbean Cafe & Upscale Lounge", 'Oasis Goodtime Emporium', "Tony's Sports Bar & Grill", 'Life Dances On', 'Cloud 9 Hookah Lounge and Cafe', 'Cafe 290', 'Three Sheets', 'Karaoke Melody', 'Doll House', 'Karaoke Melody 2', 'Atlanta Sound and Lighting', 'Happy Karaoke', 'Downwind Restaurant and Lounge', 'Java Monkey Band', '钱柜 Party World KTV & Bar', 'EarthTran Global Limousine and Transportation Services', 'Full room', 'Crowne Sports Bar & Grill', 'Happy Family Karaoke', 'Austin The Donkey Foster']
# 20

# %%
target_coordinates = "33.94278, -84.31778"
target_search="museum"
target_radius=8000
target_type= "museum"
key='AIzaSyDC-djfofoGw5HOynqam0Hw5YHhG2gwuW4'

params={
    "target_search":target_search,
    "location":target_coordinates,
    "radius":target_radius,
    "type": target_type,
     "key":key
}

base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response=requests.get(base_url, params=params)

places_data=response.json()

museums_30338 = []
for item in places_data["results"]:
    museums_30338.append(item["name"])
print(museums_30338)

n_museums_30338=len(museums_30338)
print(n_museums_30338)
# Out:
# ['Oglethorpe University Museum of Art', 'Williams Payne House', 'Black History Store', 'Green Gap Technologies', 'Atlanta Art Conservation Center', 'Wine Donation Center', 'Gipp Museums Inc', 'Rock Cave', 'Palazzo DaVenzia', 'Studio DaVenzia', 'Bus Spot', 'Carriage Lake', 'Parque']
# 13

# %%
placedata_df= {
    "Zip Code":['30341','30022','30043','30328','30062', '30308','30338'],
    "Grocery Stores":[n_groceries_30341, n_groceries_30022, n_groceries_30043, n_groceries_30328, n_groceries_30062, n_groceries_30308, n_groceries_30338],
                          "Cafes":[n_cafes_30341, n_cafes_30022, n_cafes_30043, n_cafes_30328, n_cafes_30062, n_cafes_30308, n_cafes_30338],
    "Clothing Stores":[n_clothingstores_30341, n_clothingstores_30022, n_clothingstores_30043, n_clothingstores_30328, n_clothingstores_30062, n_clothingstores_30308, n_clothingstores_30338],
    "Bus Stops":[n_busstations_30341, n_busstations_30022, n_busstations_30043, n_busstations_30328, n_busstations_30062, n_busstations_30308, n_busstations_30338],
    "Night Clubs":[n_nightclubs_30341, n_nightclubs_30022, n_nightclubs_30043, n_nightclubs_30328, n_nightclubs_30062, n_nightclubs_30308, n_nightclubs_30338],
    "Museums":[n_museums_30341, n_museums_30022, n_museums_30043, n_museums_30328, n_museums_30062, n_museums_30308, n_museums_30338]
    
}
placedata_df
# Out:
# {'Zip Code': ['30341', '30022', '30043', '30328', '30062', '30308', '30338'],
#  'Grocery Stores': [20, 20, 18, 20, 20, 20, 20],
#  'Cafes': [20, 20, 20, 20, 20, 20, 20],
#  'Clothing Stores': [20, 20, 20, 20, 20, 20, 20],
#  'Bus Stops': [20, 20, 20, 20, 20, 20, 20],
#  'Night Clubs': [20, 13, 11, 16, 14, 20, 20],
#  'Museums': [14, 2, 11, 9, 18, 20, 13]}

# %%
location_df=pd.DataFrame(placedata_df)
location_df
# Out:
#   Zip Code  Grocery Stores  Cafes  Clothing Stores  Bus Stops  Night Clubs  \
# 0    30341              20     20               20         20           20
# 1    30022              20     20               20         20           13
# 2    30043              18     20               20         20           11
# 3    30328              20     20               20         20           16
# 4    30062              20     20               20         20           14
# 5    30308              20     20               20         20           20
# 6    30338              20     20               20         20           20
#
#    Museums
# 0       14
# 1        2
# 2       11
# 3        9
# 4       18
# 5       20
# 6       13

# %%
location_csv=location_df.to_csv('location.csv')
location_csv

# %%
x_axis=location_df['Zip Code']
y_axis=location_df['Museums']
plt.bar(x_axis, y_axis, align="center")
tick_locations = [value for value in x_axis]

plt.xticks(tick_locations, x_axis)
plt.title("Museums by Zip Code")
plt.xlabel("Zip Codes")
plt.ylabel("Number of Museums")
plt.show()

# %%
x_axis=location_df['Zip Code']
y_axis=location_df['Night Clubs']
plt.bar(x_axis, y_axis, color= "purple",align="center")
tick_locations = [value for value in x_axis]

plt.xticks(tick_locations, x_axis)
plt.title("Night Clubs by Zip Code")
plt.xlabel("Zip Codes")
plt.ylabel("Number of Night Clubs")
plt.show()

# %%
x_axis=location_df['Zip Code']
y_axis=location_df['Grocery Stores']
plt.bar(x_axis, y_axis, color= "yellow",align="center")
tick_locations = [value for value in x_axis]

plt.xticks(tick_locations, x_axis)
plt.title("Grocery Stores by Zip Code")
plt.xlabel("Zip Codes")
plt.ylabel("Number of Grocery Stores")
plt.show()

# %%
x_axis=location_df['Zip Code']
y_axis=location_df['Cafes']
plt.bar(x_axis, y_axis, color= "tan",align="center")
tick_locations = [value for value in x_axis]

plt.xticks(tick_locations, x_axis)
plt.title("Cafes by Zip Code")
plt.xlabel("Zip Codes")
plt.ylabel("Number of Cafes")
plt.show()

# %%
x_axis=location_df['Zip Code']
y_axis=location_df['Clothing Stores']
plt.bar(x_axis, y_axis, color= "red",align="center")
tick_locations = [value for value in x_axis]

plt.xticks(tick_locations, x_axis)
plt.title("Clothing Stores by Zip Code")
plt.xlabel("Zip Codes")
plt.ylabel("Number of Clothing Stores")
plt.show()

# %%
x_axis=location_df['Zip Code']
y_axis=location_df['Bus Stops']
plt.bar(x_axis, y_axis, color= "green",align="center")
tick_locations = [value for value in x_axis]

plt.xticks(tick_locations, x_axis)
plt.title("Bus Stops by Zip Code")
plt.xlabel("Zip Codes")
plt.ylabel("Number of Bus Stops")
plt.show()
